# %%
import torch
import torch.nn as nn
import numpy as np
import scanpy as sc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       3 import numpy as np
#       4 import scanpy as sc
# ----> 5 from notebooks.transformer.llm import Transformer
#
# ModuleNotFoundError: No module named 'notebooks.transformer'

# %%
adata = sc.read_h5ad('/orcd/archive/abugoot/001/Projects/dlesman/datasets/satija_IFNB_HVG_and_perturbed_genes_raw.h5ad')

# %%
observation_groups = adata.obs.groupby(['gene', 'cell_type','Batch_info'])

adata.obs['group_id'] = observation_groups.ngroup()

adata.obs[adata.obs['group_id'] == 1]
# Out:
#                             orig.ident  nCount_RNA  nFeature_RNA     sample  \
# 07_02_54_1_1_1_1_1_1_1_1_2           7        7170          3435  A549_IFNB
# 07_68_35_1_1_1_1_1_1_1_1_2           7        6640          3089  A549_IFNB
# 06_32_04_1_1_1_1_1_1_1_1_2           6        5790          2836  A549_IFNB
# 06_70_83_1_1_1_1_1_1_1_1_2           6        5396          2743  A549_IFNB
# 07_59_07_1_1_1_1_1_1_1_1_2           7        4849          2465  A549_IFNB
# ...                                ...         ...           ...        ...
# 08_47_49_2_2                         8        3798          2176  A549_IFNB
# 05_66_58_2_2                         5        3643          2134  A549_IFNB
# 05_25_13_2_2                         5        3068          1773  A549_IFNB
# 05_25_03_2_2                         5        3067          1728  A549_IFNB
# 05_04_79_2_2                         5        2706          1678  A549_IFNB
#
# ...

# %%
adata[observation_groups.indices[('ADAR', 'A549', 'Rep1')]].obs['group'] = 1

adata.obs
# Out:
# /tmp/ipykernel_1799883/2445355060.py:1: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata[observation_groups.indices[('ADAR', 'A549', 'Rep1')]].obs['group'] = 1
#                             orig.ident  nCount_RNA  nFeature_RNA     sample  \
# 07_48_88_1_1_1_1_1_1_1_1_1           7        9816          4122  A549_IFNB
# 06_04_63_1_1_1_1_1_1_1_1_1           6        9359          4112  A549_IFNB
# 06_28_67_1_1_1_1_1_1_1_1_1           6        8999          3854  A549_IFNB
# 06_27_93_1_1_1_1_1_1_1_1_1           6        8384          3600  A549_IFNB
# 06_81_38_1_1_1_1_1_1_1_1_1           6        7925          3580  A549_IFNB
# ...                                ...         ...           ...        ...
# 09_10_48_2_2                         9        2362          1491  MCF7_IFNB
# 10_73_27_2_2                        10        2143          1483  MCF7_IFNB
# ...

# %%
# Assign to each observation it's group

for i, key in enumerate(list(observation_groups.indices)[:2]):
    print(key)
    adata[observation_groups.indices[key]].obs['group'] = i 

adata.obs
# Out:
# ('ADAR', 'A549', 'Rep1')
# /tmp/ipykernel_1799883/336399944.py:5: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata[observation_groups.indices[key]].obs['group'] = i
# ('ADAR', 'A549', 'Rep2')
# /tmp/ipykernel_1799883/336399944.py:5: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata[observation_groups.indices[key]].obs['group'] = i
#                             orig.ident  nCount_RNA  nFeature_RNA     sample  \
# 07_48_88_1_1_1_1_1_1_1_1_1           7        9816          4122  A549_IFNB
# 06_04_63_1_1_1_1_1_1_1_1_1           6        9359          4112  A549_IFNB
# 06_28_67_1_1_1_1_1_1_1_1_1           6        8999          3854  A549_IFNB
# 06_27_93_1_1_1_1_1_1_1_1_1           6        8384          3600  A549_IFNB
# 06_81_38_1_1_1_1_1_1_1_1_1           6        7925          3580  A549_IFNB
# ...
