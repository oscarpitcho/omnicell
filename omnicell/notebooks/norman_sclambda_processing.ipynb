# %%
import scanpy as sc
import numpy

# %%
data_path = "/orcd/data/omarabu/001/opitcho/norman_preprocessed.h5ad"
adata = sc.read(data_path)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 111122 × 5044
#     obs: 'guide_id', 'read_count', 'UMI_count', 'coverage', 'gemgroup', 'good_coverage', 'number_of_cells', 'tissue_type', 'cell_line', 'cancer', 'disease', 'perturbation_type', 'celltype', 'organism', 'perturbation', 'nperts', 'ngenes', 'ncounts', 'percent_mito', 'percent_ribo', 'n_counts', 'condition', 'pert_type', 'cell_type', 'source', 'condition_ID', 'control', 'dose_value', 'pathway', 'cov_cond', 'pert', 'split_hardest', 'split_1', 'split_2', 'split_3', 'split_4', 'split_5', 'split_6', 'cond_harm', 'phase'
#     var: 'ensemble_id', 'ncounts', 'ncells', 'symbol', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'cell_type_colors', 'gene_embedding_path', 'hvg', 'log1p', 'neighbors', 'rank_genes_groups_cov', 'source_colors', 'split_1_colors', 'split_2_colors', 'split_3_colors', 'split_4_colors', 'split_5_colors', 'split_hardest_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'counts'
# ...

# %%
adata.obs
# Out:
#                                              guide_id  read_count  UMI_count  \
# CCCATACCATTCTTAC-7          UBASH3B_OSR2;UBASH3B_OSR2        1282         64
# CTCATTAGTAAGAGAG-5            FOXL2_HOXB9;FOXL2_HOXB9        2083         76
# CACACCTCATGAACCT-3  TSC22D1_NegCtrl0;TSC22D1_NegCtrl0        2445        121
# AGATCTGTCACCAGGC-8        MIDN_NegCtrl0;MIDN_NegCtrl0        1004         46
# ATGTGTGCAAGCCGCT-5          MAP2K3_IKZF3;MAP2K3_IKZF3        2035         51
# ...                                               ...         ...        ...
# ATTATCCAGCCAGTTT-5      NegCtrl0_FOXF1;NegCtrl0_FOXF1           2          1
# GTACTCCAGACTAGGC-2        NegCtrl0_SPI1;NegCtrl0_SPI1        2373        149
# GCTTGAAAGAGGACGG-6        SGK1_NegCtrl0;SGK1_NegCtrl0         392         17
# TGCTACCTCAGGTAAA-4        TP73_NegCtrl0;TP73_NegCtrl0        1491         84
# GTCGTAACAAGTTAAG-1      CELF2_NegCtrl0;CELF2_NegCtrl0         691         41
#
# ...

# %%
adata.obs[adata.obs["cond_harm"] == 'ctrl']
# Out:
#                                                  guide_id  read_count  \
# ACTGATGGTCGCATCG-6  NegCtrl11_NegCtrl0;NegCtrl11_NegCtrl0        1225
# ACGAGCCAGGGATCTG-3  NegCtrl10_NegCtrl0;NegCtrl10_NegCtrl0         491
# GACTACACACCATCCT-5    NegCtrl0_NegCtrl0;NegCtrl0_NegCtrl0        3247
# CATTATCTCAGCTGGC-5  NegCtrl10_NegCtrl0;NegCtrl10_NegCtrl0        3727
# GACGCGTAGTTTCCTT-1    NegCtrl0_NegCtrl0;NegCtrl0_NegCtrl0        1080
# ...                                                   ...         ...
# AGGGAGTGTAAGGGCT-1  NegCtrl11_NegCtrl0;NegCtrl11_NegCtrl0         865
# AACACGTCAAGCGCTC-5  NegCtrl10_NegCtrl0;NegCtrl10_NegCtrl0        3093
# AACGTTGAGATATGGT-6  NegCtrl11_NegCtrl0;NegCtrl11_NegCtrl0         677
# CAGCTGGGTTAGTGGG-5  NegCtrl11_NegCtrl0;NegCtrl11_NegCtrl0        1699
# CTGTGCTAGGATCGCA-5    NegCtrl0_NegCtrl0;NegCtrl0_NegCtrl0        2199
#
#                     UMI_count   coverage  gemgroup  good_coverage  \
# ...

# %%
import numpy as np
unlogged = np.exp(adata.X) - 1

# %%
unlogged.sum(axis = 1)
# Out:
# array([2343.5076, 2754.1724, 2385.5547, ..., 2926.0732, 2726.3037,
#        2410.1594], dtype=float32)
