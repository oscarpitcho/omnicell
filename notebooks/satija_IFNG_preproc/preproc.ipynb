# %%
import scanpy as sc

# %%
adata = sc.read('/orcd/data/omarabu/001/Omnicell_datasets/satija_IFNG_raw/Seurat_IFNG.h5ad')

# %%
adata.obs
# Out:
#                             orig.ident  nCount_RNA  nFeature_RNA     sample  \
# 05_54_42_1_1_1_1_1_1_1_1_1           5       15381          5362  A549_IFNG
# 08_58_81_1_1_1_1_1_1_1_1_1           8       13534          4995  A549_IFNG
# 06_01_92_1_1_1_1_1_1_1_1_1           6       11520          4454  A549_IFNG
# 05_33_45_1_1_1_1_1_1_1_1_1           5       11174          4575  A549_IFNG
# 06_35_73_1_1_1_1_1_1_1_1_1           6       10807          3961  A549_IFNG
# ...                                ...         ...           ...        ...
# 10_82_89_2_2                        10        1102           872  MCF7_IFNG
# 10_30_41_2_2                        10        1083           824  MCF7_IFNG
# 10_09_53_2_2                        10        1071           845  MCF7_IFNG
# 09_96_96_2_2                         9         941           781  MCF7_IFNG
# 12_77_43_2_2                        12         938           655  MCF7_IFNG
#
# ...

# %%
adata.var['gene'] = adata.var['c..TSPAN6....TNMD....DPM1....SCYL3....C1orf112....FGR....CFH...']

# %%
adata.var_names = adata.var['gene']

# %%
adata.var
# Out:
#            c..TSPAN6....TNMD....DPM1....SCYL3....C1orf112....FGR....CFH...  \
# gene
# TSPAN6                                                 TSPAN6
# TNMD                                                     TNMD
# DPM1                                                     DPM1
# SCYL3                                                   SCYL3
# C1orf112                                             C1orf112
# ...                                                       ...
# AC068620.2                                         AC068620.2
# AC006023.1                                         AC006023.1
# AL356121.2                                         AL356121.2
# TAF9BP2                                               TAF9BP2
# AC016065.2                                         AC016065.2
#
#                   gene
# gene
# TSPAN6          TSPAN6
# TNMD              TNMD
# DPM1              DPM1
# SCYL3            SCYL3
# C1orf112      C1orf112
# ...                ...
# AC068620.2  AC068620.2
# ...

# %%
adata.write('/orcd/data/omarabu/001/Omnicell_datasets/satija_IFNG_raw/Seurat_IFNG.h5ad')

# %%
adata.X
# Out:
# <245240x33525 sparse matrix of type '<class 'numpy.float64'>'
# 	with 667070362 stored elements in Compressed Sparse Column format>
