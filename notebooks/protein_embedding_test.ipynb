# %%
# !wget -O human_pt5.h5 https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/embeddings/UP000005640_9606/per-protein.h5
# Out:
# --2025-01-21 14:42:52--  https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/embeddings/UP000005640_9606/per-protein.h5
# Resolving ftp.uniprot.org (ftp.uniprot.org)... 128.175.240.195
# Connecting to ftp.uniprot.org (ftp.uniprot.org)|128.175.240.195|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51221456 (49M)
# Saving to: ‘human_pt5.h5’
#
# 100%[======================================>] 51,221,456  27.9MB/s   in 1.8s
#
# 2025-01-21 14:42:54 (27.9 MB/s) - ‘human_pt5.h5’ saved [51221456/51221456]

# %%
import h5py
import torch

# %%
file_path = "human_pt5.h5"
output_path = "gene_emb_prottrans5.pt"

# Open the h5 file
with h5py.File(file_path, "r") as h5_file:
    # Extract gene names and embeddings
    gene_names = list(h5_file.keys())
    repr_list = [torch.tensor(h5_file[gene_name][:]) for gene_name in gene_names]

# Stack embeddings into a single tensor
repr_tensor = torch.stack(repr_list)

# Create the desired dictionary format
data = {
    "gene_names": gene_names,
    "repr": repr_tensor
}

# %%
'P17181' in data["gene_names"]


repr_tensor.shape
# Out:
# torch.Size([20647, 1024])

# %%
from omnicell.data.catalogue import Catalogue
import scanpy as sc

# %%
dd = Catalogue.get_dataset_details("satija_IFNB_raw")

adata = sc.read(dd.path)

# %%
gene_names = list(adata.var_names)
gene_names
# Out:
# ['TSPAN6',
#  'TNMD',
#  'DPM1',
#  'SCYL3',
#  'C1orf112',
#  'FGR',
#  'CFH',
#  'FUCA2',
#  'GCLC',
#  'NFYA',
#  'STPG1',
#  'NIPAL3',
#  'LAS1L',
#  'ENPP4',
#  'SEMA3F',
#  'CFTR',
#  'ANKIB1',
#  'CYP51A1',
#  'KRIT1',
#  'RAD52',
#  'MYH16',
#  'BAD',
#  'LAP3',
#  'CD99',
#  'HS3ST1',
#  'AOC1',
#  'WNT16',
#  'HECW1',
#  'MAD1L1',
#  'LASP1',
#  'SNX11',
#  'M6PR',
#  'KLHL13',
#  'CYP26B1',
#  'ICA1',
#  'DBNDD1',
#  'ALS2',
#  'CASP10',
#  'CFLAR',
#  'TFPI',
#  'NDUFAF7',
#  'RBM5',
#  'MTMR7',
#  'SLC7A2',
#  'ARF5',
#  'SARM1',
#  'POLDIP2',
#  'PLXND1',
#  'AK2',
#  'CD38',
#  'FKBP4',
#  'KDM1A',
#  'RBM6',
#  'CAMKK1',
#  'RECQL',
#  'VPS50',
#  'HSPB6',
#  'ARHGAP33',
#  'NDUFAB1',
#  'PDK4',
#  'SLC22A16',
#  'ZMYND10',
#  'ABCB5',
#  'ARX',
#  'SLC25A13',
#  'ST7',
#  'CDC27',
#  'SLC4A1',
#  'CALCR',
#  'HCCS',
#  'DVL2',
#  'PRSS22',
#  'UPF1',
#  'SKAP2',
#  'SLC25A5',
#  'MCUB',
#  'HOXA11',
#  'POLR2J',
#  'DHX33',
#  'MEOX1',
#  'THSD7A',
#  'LIG3',
# ...

# %%
from bioservices import UniProt

uniprot = UniProt()
# Use 'Gene_Name' instead of 'GENENAME' and 'UniProtKB' instead of 'ID'
result = uniprot.mapping(fr='Gene_Name', to='UniProtKB', query=gene_names[:100])
print(result)
# Out:
#  93%|█████████▎| 2421/2599 [16:28<01:12,  2.45it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 5
#       3 uniprot = UniProt()
#       4 # Use 'Gene_Name' instead of 'GENENAME' and 'UniProtKB' instead of 'ID'
# ----> 5 result = uniprot.mapping(fr='Gene_Name', to='UniProtKB', query=gene_names[:100])
#       6 print(result)
#
# File /orcd/data/omarabu/001/opitcho/miniforge3/envs/huggingface/lib/python3.9/site-packages/bioservices/uniprot.py:487, in UniProt.mapping(self, fr, to, query, polling_interval_seconds, max_waiting_time, progress)
#     485 for x in tqdm.tqdm(range(size, total, size), disable=not progress):
#     486     link = self._get_next_link(self.services.last_response.headers)
# --> 487     batch = self.services.http_get(link, frmt="json")
#     488     batches += batch["results"]
#     489     fails += results.get("failedIds", [])
#
# ...

# %%
result

# %%
if result and 'results' in result:
    entry = result['results'][0]  # Get first result
    uniprot_id = entry['to']['primaryAccession']
    uniprot_name = entry['to']['uniProtkbId']
    print(f"UniProt ID: {uniprot_id}")
    print(f"UniProt Name: {uniprot_name}")
    
    # Print additional info if needed
    print(f"Secondary accessions: {entry['to']['secondaryAccessions']}")
    print(f"Annotation score: {entry['to']['annotationScore']}")
    print(f"Organism: {entry['to']['organism']['scientificName']}")
