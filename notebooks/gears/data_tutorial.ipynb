# %% [markdown]
# ## (1) Load Processed Data in the Paper
#
# Currently, we support norman / adamson / dixit.

# %%
import sys
sys.path.append('../../')

from omnicell.models.gears.pertdata import PertData

# %% [markdown]
# ## (2) Create your own Perturb-Seq data
# Prepare a scanpy adata object with
# 1. `adata.obs` dataframe has `condition` and `cell_type` columns, where `condition` is the perturbation name for each cell. Control cells have condition format of `ctrl`, single perturbation has condition format of `A+ctrl` or `ctrl+A`, combination perturbation has condition format of `A+B`.
# 2. `adata.var` dataframe has `gene_name` column, where each gene name is the gene symbol.
# 3. `adata.X` stores the post-perturbed gene expression.
#
# Here an example using dixit 2016 dataset.

# %%
import scanpy as sc
adata = sc.read('/orcd/data/omarabu/001/Omnicell_datasets/satija_IFNB_raw/Seurat_IFNB.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 328542 × 34025
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'sample', 'bc1_well', 'bc2_well', 'bc3_well', 'percent.mito', 'cell_type', 'pathway', 'RNA_snn_res.0.9', 'seurat_clusters', 'sample_ID', 'Batch_info', 'guide', 'gene', 'mixscale_score'
#     var: 'gene'

# %%
adata.var["gene_name"] = adata.var["gene"]
adata.obs["condition"] = adata.obs["gene"]

# %%
#We relabel NT as ctrl and all other entries as some_entry+ctrl

perts = [p for p in adata.obs["condition"].unique() if p != "NT"]
adata.obs["condition"] = adata.obs["condition"].replace({"NT":"ctrl"})
adata.obs["condition"] = adata.obs["condition"].replace({p:p+"+ctrl" for p in perts})

# %%
adata.obs
# Out:
#                             orig.ident  nCount_RNA  nFeature_RNA     sample  \
# 07_48_88_1_1_1_1_1_1_1_1_1           7        9816          4122  A549_IFNB
# 06_04_63_1_1_1_1_1_1_1_1_1           6        9359          4112  A549_IFNB
# 06_28_67_1_1_1_1_1_1_1_1_1           6        8999          3854  A549_IFNB
# 06_27_93_1_1_1_1_1_1_1_1_1           6        8384          3600  A549_IFNB
# 06_81_38_1_1_1_1_1_1_1_1_1           6        7925          3580  A549_IFNB
# ...                                ...         ...           ...        ...
# 09_10_48_2_2                         9        2362          1491  MCF7_IFNB
# 10_73_27_2_2                        10        2143          1483  MCF7_IFNB
# 10_24_48_2_2                        10        1921          1322  MCF7_IFNB
# 10_12_27_2_2                        10        1676          1169  MCF7_IFNB
# 10_83_89_2_2                        10        1538          1168  MCF7_IFNB
#
#                            bc1_well bc2_well bc3_well  percent.mito cell_type  \
# 07_48_88_1_1_1_1_1_1_1_1_1       A7      D12       H4      1.161369      A549
# 06_04_63_1_1_1_1_1_1_1_1_1       A6       A4       F3      3.835880      A549
# 06_28_67_1_1_1_1_1_1_1_1_1       A6       C4       F7      9.189910      A549
# 06_27_93_1_1_1_1_1_1_1_1_1       A6       C3       H9      3.268130      A549
# 06_81_38_1_1_1_1_1_1_1_1_1       A6       G9       D2      3.798107      A549
# ...                             ...      ...      ...           ...       ...
# 09_10_48_2_2                     A9      A10      D12      1.820491      MCF7
# 10_73_27_2_2                    A10       G1       C3      0.326645      MCF7
# 10_24_48_2_2                    A10      B12      D12      6.507028      MCF7
# 10_12_27_2_2                    A10      A12       C3      2.923628      MCF7
# 10_83_89_2_2                    A10      G11       H5      1.820546      MCF7
#
#                            pathway  RNA_snn_res.0.9  seurat_clusters  \
# 07_48_88_1_1_1_1_1_1_1_1_1    IFNB             15.0             15.0
# 06_04_63_1_1_1_1_1_1_1_1_1    IFNB             15.0             15.0
# 06_28_67_1_1_1_1_1_1_1_1_1    IFNB             15.0             15.0
# 06_27_93_1_1_1_1_1_1_1_1_1    IFNB             15.0             15.0
# 06_81_38_1_1_1_1_1_1_1_1_1    IFNB             15.0             15.0
# ...                            ...              ...              ...
# 09_10_48_2_2                  IFNB              NaN              NaN
# 10_73_27_2_2                  IFNB              NaN              NaN
# 10_24_48_2_2                  IFNB              NaN              NaN
# 10_12_27_2_2                  IFNB              NaN              NaN
# 10_83_89_2_2                  IFNB              NaN              NaN
#
#                             sample_ID Batch_info     guide    gene  \
# 07_48_88_1_1_1_1_1_1_1_1_1   sample_1       Rep1  TRAFD1g3  TRAFD1
# 06_04_63_1_1_1_1_1_1_1_1_1   sample_1       Rep1    HES4g3    HES4
# 06_28_67_1_1_1_1_1_1_1_1_1   sample_1       Rep1      NTg8      NT
# 06_27_93_1_1_1_1_1_1_1_1_1   sample_1       Rep1  STAT5Ag1  STAT5A
# 06_81_38_1_1_1_1_1_1_1_1_1   sample_1       Rep1   STAT4g2   STAT4
# ...                               ...        ...       ...     ...
# 09_10_48_2_2                sample_16       Rep2  NFE2L3g3  NFE2L3
# 10_73_27_2_2                sample_16       Rep2    IRF3g2    IRF3
# 10_24_48_2_2                sample_16       Rep2   STAT6g2   STAT6
# 10_12_27_2_2                sample_16       Rep2   HERC5g3   HERC5
# 10_83_89_2_2                sample_16       Rep2   MAPK8g2   MAPK8
#
#                             mixscale_score    condition
# 07_48_88_1_1_1_1_1_1_1_1_1       -0.290358  TRAFD1+ctrl
# 06_04_63_1_1_1_1_1_1_1_1_1        0.121449    HES4+ctrl
# 06_28_67_1_1_1_1_1_1_1_1_1        0.000000         ctrl
# 06_27_93_1_1_1_1_1_1_1_1_1        0.377627  STAT5A+ctrl
# 06_81_38_1_1_1_1_1_1_1_1_1        1.000000   STAT4+ctrl
# ...                                    ...          ...
# 09_10_48_2_2                     -0.009685  NFE2L3+ctrl
# 10_73_27_2_2                     -0.402627    IRF3+ctrl
# 10_24_48_2_2                     -0.356580   STAT6+ctrl
# 10_12_27_2_2                     -0.045158   HERC5+ctrl
# 10_83_89_2_2                      4.383990   MAPK8+ctrl
#
# [328542 rows x 18 columns]

# %% [markdown]
# ### Suggested normalization
#
# For raw count data we recommend the following normalization and subsetting to the top 5000 most variable genes

# %%
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata,n_top_genes=5000, subset=True)

# %% [markdown]
# ### Create dataloader
#
# GEARS will take it from here. The new data processing takes around 15 minutes for 5K genes and 100K cells.

# %%
import sys
sys.path.append('../')

from omnicell.models.gears.pertdata import PertData

pert_data = PertData('./data') # specific saved folder
pert_data.new_data_process(dataset_name = 'satija', adata = adata) # specific dataset name and adata object
print(f"Data processed and saved in {pert_data.data_path}")
pert_data.load(data_path = './data/satija') # load the processed data, the path is saved folder + dataset_name
print(f"Data loaded from {pert_data.data_path}")
pert_data.prepare_split(split = 'simulation', seed = 1) # get data split with seed
print(f"Data split with seed 1")
pert_data.get_dataloader(batch_size = 32, test_batch_size = 128) # prepare data loader
print(f"Data loader prepared")
# Out:
# Found local copy...
# Found local copy...
# Creating pyg object for each cell in the data...
# Creating dataset file...
#   0%|          | 0/62 [00:00<?, ?it/s]TEEST TIMER: 0.00 seconds
# Adata shape: (5339, 5000)
# Duration for double loop in TRAFD1+ctrl: 1074.72 seconds
#   0%|          | 0/62 [17:54<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 7
#       4 from omnicell.models.gears.pertdata import PertData
#       6 pert_data = PertData('./data') # specific saved folder
# ----> 7 pert_data.new_data_process(dataset_name = 'satija', adata = adata) # specific dataset name and adata object
#       8 print(f"Data processed and saved in {pert_data.data_path}")
#       9 pert_data.load(data_path = './data/satija') # load the processed data, the path is saved folder + dataset_name
#
# File /orcd/data/omarabu/001/opitcho/omnicell/omnicell/notebooks/gears/../../omnicell/models/gears/pertdata.py:274, in PertData.new_data_process(self, dataset_name, adata, skip_calc_de)
#     272 dataset_fname = os.path.join(pyg_path, 'cell_graphs.pkl')
#     273 print_sys("Creating pyg object for each cell in the data...")
# --> 274 self.create_dataset_file()
#     275 print_sys("Saving new dataset pyg object at " + dataset_fname)
#     276 pickle.dump(self.dataset_processed, open(dataset_fname, "wb"))
#
# File /orcd/data/omarabu/001/opitcho/omnicell/omnicell/notebooks/gears/../../omnicell/models/gears/pertdata.py:641, in PertData.create_dataset_file(self)
#     639 self.dataset_processed = {}
#     640 for p in tqdm(self.adata.obs['condition'].unique()):
# --> 641     self.dataset_processed[p] = self.create_cell_graph_dataset(self.adata, p)
#     642 print_sys("Done!")
#
# File /orcd/data/omarabu/001/opitcho/omnicell/omnicell/notebooks/gears/../../omnicell/models/gears/pertdata.py:625, in PertData.create_cell_graph_dataset(self, split_adata, pert_category, num_samples)
#     623 with timer(f"Creating cell graphs for {pert_category}, iterating over {len(Xs)} cells"):
#     624     temp = zip(Xs, ys)
# --> 625     for i, X, y in enumerate(temp):
#     626         cell_graph = None
#     627         with timer(f"Iteraration {i}/{len(temp)} took: "):
#
# ValueError: not enough values to unpack (expected 3, got 2)
