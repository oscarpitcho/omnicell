# %% [markdown]
# ## (1) Load Processed Data in the Paper
#
# Currently, we support norman / adamson / dixit.

# %%
import sys
sys.path.append('../../')

from omnicell.models.gears.pertdata import PertData
from omnicell.data.catalogue import Catalogue

# %% [markdown]
# ## (2) Create your own Perturb-Seq data
# Prepare a scanpy adata object with
# 1. `adata.obs` dataframe has `condition` and `cell_type` columns, where `condition` is the perturbation name for each cell. Control cells have condition format of `ctrl`, single perturbation has condition format of `A+ctrl` or `ctrl+A`, combination perturbation has condition format of `A+B`.
# 2. `adata.var` dataframe has `gene_name` column, where each gene name is the gene symbol.
# 3. `adata.X` stores the post-perturbed gene expression.
#
# Here an example using dixit 2016 dataset.

# %%
import scanpy as sc
dd = Catalogue.get_dataset_details('repogle_k562_essential_raw')
adata = sc.read(dd.path)
adata
# Out:
# AnnData object with n_obs × n_vars = 310385 × 8563
#     obs: 'gem_group', 'gene', 'gene_id', 'transcript', 'gene_transcript', 'sgID_AB', 'mitopercent', 'UMI_count', 'z_gemgroup_UMI', 'core_scale_factor', 'core_adjusted_UMI_count', 'cell_type'
#     var: 'gene_name', 'chr', 'start', 'end', 'class', 'strand', 'length', 'in_matrix', 'mean', 'std', 'cv', 'fano', 'gene_id'

# %%
adata.obs["condition"] = adata.obs["gene"]

# %%
#We relabel NT as ctrl and all other entries as some_entry+ctrl

perts = [p for p in adata.obs["condition"].unique() if p != dd.control]
adata.obs["condition"] = adata.obs["condition"].replace({dd.control:"ctrl"})
adata.obs["condition"] = adata.obs["condition"].replace({p:p+"+ctrl" for p in perts})

# %%
adata.obs
# Out:
#                      gem_group     gene          gene_id transcript  \
# cell_barcode
# AAACCCAAGAAATCCA-27         27     NAF1  ENSG00000145414       P1P2
# AAACCCAAGAACTTCC-31         31     BUB1  ENSG00000169679       P1P2
# AAACCCAAGAAGCCAC-34         34     UBL5  ENSG00000198258       P1P2
# AAACCCAAGAATAGTC-43         43  C9orf16  ENSG00000171159       P1P2
# AAACCCAAGACAGCGT-28         28    TIMM9  ENSG00000100575       P1P2
# ...                        ...      ...              ...        ...
# TTTGTTGTCTGTCGTC-45         45  ATP6V1D  ENSG00000100554       P1P2
# TTTGTTGTCTGTCTCG-27         27    CNOT3  ENSG00000088038       P1P2
# TTTGTTGTCTGTGCGG-44         44   METTL3  ENSG00000165819       P1P2
# TTTGTTGTCTTGCAGA-14         14     RPL5  ENSG00000122406       P1P2
# TTTGTTGTCTTTACAC-25         25   SEC61B  ENSG00000106803       P1P2
#
#                                        gene_transcript  \
# cell_barcode
# AAACCCAAGAAATCCA-27     5449_NAF1_P1P2_ENSG00000145414
# AAACCCAAGAACTTCC-31      935_BUB1_P1P2_ENSG00000169679
# AAACCCAAGAAGCCAC-34     9534_UBL5_P1P2_ENSG00000198258
# AAACCCAAGAATAGTC-43  1131_C9orf16_P1P2_ENSG00000171159
# AAACCCAAGACAGCGT-28    8927_TIMM9_P1P2_ENSG00000100575
# ...                                                ...
# TTTGTTGTCTGTCGTC-45   682_ATP6V1D_P1P2_ENSG00000100554
# TTTGTTGTCTGTCTCG-27    1718_CNOT3_P1P2_ENSG00000088038
# TTTGTTGTCTGTGCGG-44   5004_METTL3_P1P2_ENSG00000165819
# TTTGTTGTCTTGCAGA-14     7475_RPL5_P1P2_ENSG00000122406
# TTTGTTGTCTTTACAC-25   7752_SEC61B_P1P2_ENSG00000106803
#
#                                                                sgID_AB  \
# cell_barcode
# AAACCCAAGAAATCCA-27  NAF1_+_164087918.23-P1P2|NAF1_-_164087674.23-P1P2
# AAACCCAAGAACTTCC-31  BUB1_-_111435363.23-P1P2|BUB1_-_111435372.23-P1P2
# AAACCCAAGAAGCCAC-34      UBL5_-_9938639.23-P1P2|UBL5_+_9938801.23-P1P2
# AAACCCAAGAATAGTC-43  C9orf16_+_130922603.23-P1P2|C9orf16_+_13092264...
# AAACCCAAGACAGCGT-28  TIMM9_-_58893843.23-P1P2|TIMM9_-_58893848.23-P1P2
# ...                                                                ...
# TTTGTTGTCTGTCGTC-45  ATP6V1D_+_67826485.23-P1P2|ATP6V1D_+_67826497....
# TTTGTTGTCTGTCTCG-27  CNOT3_+_54641532.23-P1P2|CNOT3_-_54641691.23-P1P2
# TTTGTTGTCTGTGCGG-44  METTL3_+_21979431.23-P1P2|METTL3_-_21979084.23...
# TTTGTTGTCTTGCAGA-14    RPL5_+_93297664.23-P1P2|RPL5_-_93297968.23-P1P2
# TTTGTTGTCTTTACAC-25  SEC61B_+_101984577.23-P1P2|SEC61B_-_101984591....
#
#                      mitopercent  UMI_count  z_gemgroup_UMI  \
# cell_barcode
# AAACCCAAGAAATCCA-27     0.112083    11438.0        0.013047
# AAACCCAAGAACTTCC-31     0.179895     5342.0       -1.522247
# AAACCCAAGAAGCCAC-34     0.105287    17305.0        0.384157
# AAACCCAAGAATAGTC-43     0.099359    30244.0        3.721912
# AAACCCAAGACAGCGT-28     0.137623     8407.0       -0.975371
# ...                          ...        ...             ...
# TTTGTTGTCTGTCGTC-45     0.100272    18350.0        0.428227
# TTTGTTGTCTGTCTCG-27     0.093876     8671.0       -0.633593
# TTTGTTGTCTGTGCGG-44     0.107983    20568.0        1.054624
# TTTGTTGTCTTGCAGA-14     0.128225    23568.0        1.676254
# TTTGTTGTCTTTACAC-25     0.095009    13504.0        0.341625
#
#                      core_scale_factor  core_adjusted_UMI_count cell_type  \
# cell_barcode
# AAACCCAAGAAATCCA-27           0.813253             14064.512695      k562
# AAACCCAAGAACTTCC-31           0.844107              6328.584473      k562
# AAACCCAAGAAGCCAC-34           1.091537             15853.792969      k562
# AAACCCAAGAATAGTC-43           0.948277             31893.619141      k562
# AAACCCAAGACAGCGT-28           0.868942              9674.979492      k562
# ...                                ...                      ...       ...
# TTTGTTGTCTGTCGTC-45           1.115052             16456.638672      k562
# TTTGTTGTCTGTCTCG-27           0.813253             10662.125000      k562
# TTTGTTGTCTGTGCGG-44           0.973352             21131.095703      k562
# TTTGTTGTCTTGCAGA-14           1.050055             22444.542969      k562
# TTTGTTGTCTTTACAC-25           0.855594             15783.187500      k562
#
#                         condition
# cell_barcode
# AAACCCAAGAAATCCA-27     NAF1+ctrl
# AAACCCAAGAACTTCC-31     BUB1+ctrl
# AAACCCAAGAAGCCAC-34     UBL5+ctrl
# AAACCCAAGAATAGTC-43  C9orf16+ctrl
# AAACCCAAGACAGCGT-28    TIMM9+ctrl
# ...                           ...
# TTTGTTGTCTGTCGTC-45  ATP6V1D+ctrl
# TTTGTTGTCTGTCTCG-27    CNOT3+ctrl
# TTTGTTGTCTGTGCGG-44   METTL3+ctrl
# TTTGTTGTCTTGCAGA-14     RPL5+ctrl
# TTTGTTGTCTTTACAC-25   SEC61B+ctrl
#
# [310385 rows x 13 columns]

# %% [markdown]
# ### Suggested normalization
#
# For raw count data we recommend the following normalization and subsetting to the top 5000 most variable genes

# %%
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata,n_top_genes=5000, subset=True)

# %% [markdown]
# ### Create dataloader
#
# GEARS will take it from here. The new data processing takes around 15 minutes for 5K genes and 100K cells.

# %%
from omnicell.models.gears.pertdata import PertData

pert_data = PertData('./data') # specific saved folder
pert_data.new_data_process(dataset_name = 'satija', adata = adata) # specific dataset name and adata object
print(f"Data processed and saved in {pert_data.data_path}")
pert_data.load(data_path = './data/satija') # load the processed data, the path is saved folder + dataset_name
print(f"Data loaded from {pert_data.data_path}")
pert_data.prepare_split(split = 'simulation', seed = 1) # get data split with seed
print(f"Data split with seed 1")
pert_data.get_dataloader(batch_size = 32, test_batch_size = 128) # prepare data loader
print(f"Data loader prepared")
# Out:
# Found local copy...
