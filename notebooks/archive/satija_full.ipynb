# %%
import scanpy as sc

# %%
adata = sc.read('/orcd/data/omarabu/001/Omnicell_datasets/satija_IFNB_raw/Seurat_IFNB.h5ad', backed ="r+")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 328542 × 34025 backed at '/orcd/data/omarabu/001/Omnicell_datasets/satija_IFNB_raw/Seurat_IFNB.h5ad'
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'sample', 'bc1_well', 'bc2_well', 'bc3_well', 'percent.mito', 'cell_type', 'pathway', 'RNA_snn_res.0.9', 'seurat_clusters', 'sample_ID', 'Batch_info', 'guide', 'gene', 'mixscale_score'
#     var: 'gene'

# %%
adata.var_names
# Out:
# Index(['TSPAN6', 'TNMD', 'DPM1', 'SCYL3', 'C1orf112', 'FGR', 'CFH', 'FUCA2',
#        'GCLC', 'NFYA',
#        ...
#        'AL133371.3', 'AC091304.3', 'NOS2P1', 'RN7SL376P', 'AC008622.1',
#        'AP006545.2', 'AL359198.1', 'AL360219.1', 'AL138966.2', 'AC092634.8'],
#       dtype='object', name='gene', length=34025)

# %%
adata.write('/orcd/data/omarabu/001/Omnicell_datasets/satija_IFNB_raw/Seurat_IFNB.h5ad', compression='gzip')

# %%
adata = sc.read('/orcd/data/omarabu/001/Omnicell_datasets/satija_IFNB_raw/Seurat_IFNB.h5ad')

# %%
adata.var_names
# Out:
# Index(['TSPAN6', 'TNMD', 'DPM1', 'SCYL3', 'C1orf112', 'FGR', 'CFH', 'FUCA2',
#        'GCLC', 'NFYA',
#        ...
#        'AL133371.3', 'AC091304.3', 'NOS2P1', 'RN7SL376P', 'AC008622.1',
#        'AP006545.2', 'AL359198.1', 'AL360219.1', 'AL138966.2', 'AC092634.8'],
#       dtype='object', name='gene', length=34025)
